# %%
import pandas as pd

# Import the whole dataset
df = pd.read_excel('final_dataset.xlsx', sheet_name = 0)
df
# Out:
#      Unnamed: 0    Index  Sea_level     Sea_CO2  Sea_Temperature  \
# 0             1  2003-01  11.362857  374.337369             0.08
# 1             2  2003-02   8.350000  367.689260             0.11
# 2             3  2003-03   6.470000  365.933918             0.13
# 3             4  2003-04   8.370000  383.682120             0.08
# 4             5  2003-05   5.732500  391.892556             0.05
# ..          ...      ...        ...         ...              ...
# 199         200  2019-08  69.500000  395.057044             0.44
# 200         201  2019-09  71.733333  396.693649             0.37
# 201         202  2019-10  73.000000  401.322743             0.38
# 202         203  2019-11  71.433333  385.674925             0.38
# 203         204  2019-12  68.100000  377.579679             0.39
#
#      Stratification  OCH-700  OCH-2000  Ice_index  Salinity
# 0             2.592    -4.13     -2.53     14.391   0.00382
# 1             2.948    -4.09     -2.48     15.193   0.00367
# ...

# %%
# import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
# df = pd.read_excel('path_to_your_file.xlsx')

# Convert 'Index' to datetime and set as index
df['Index'] = pd.to_datetime(df['Index'])
df.set_index('Index', inplace=True)

# Drop unnecessary columns (like 'Unnamed: 0' if it exists)
df.drop(columns=['Unnamed: 0'], inplace=True)

# Create a 4x2 subplot layout
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(15, 20))
axes = axes.flatten()  # Flatten the axes array for easy iteration

# Plot each column in the respective subplot
for i, column in enumerate(df.columns):
    axes[i].plot(df.index, df[column], marker='o', linestyle='-')
    axes[i].set_title(column)
    axes[i].grid(True)

# Adjust layout for better readability
plt.tight_layout()

# Save the plot
# plt.savefig('summary.png')

plt.show()

# %%
# # import pandas as pd
# import matplotlib.pyplot as plt

# # Load the dataset
# # df = pd.read_excel('path_to_your_file.xlsx')

# # Convert 'Index' to datetime and set as index
# df['Index'] = pd.to_datetime(df['Index'])
# df.set_index('Index', inplace=True)

# # Drop unnecessary columns (like 'Unnamed: 0' if it exists)
# df.drop(columns=['Unnamed: 0'], inplace=True)

# # Plot each column
# for column in df.columns:
#     plt.figure(figsize=(10, 5))
#     plt.plot(df.index, df[column], marker='o', linestyle='-')
#     plt.title(column)
#     plt.xlabel('Date')
#     plt.ylabel(column)
#     plt.grid(True)
#     plt.show()

# %%
# Assuming df is already loaded and contains the required columns

# Summary for columns 'Sea_level' to 'Stratification'
cols_group_1 = ['Sea_level', 'Sea_CO2', 'Sea_Temperature', 'Stratification']
summary_df1 = df[cols_group_1].agg(['max', 'min', 'mean', 'sem'])  # sem is standard error of the mean

# Summary for columns 'OCH-700' to 'Sanlinity'
cols_group_2 = ['OCH-700', 'OCH-2000', 'Ice_index', 'Salinity']
summary_df2 = df[cols_group_2].agg(['max', 'min', 'mean', 'sem'])

# summary_df1 and summary_df2 now hold the respective summaries
print(summary_df1)
print(summary_df2)
# Out:
#       Sea_level     Sea_CO2  Sea_Temperature  Stratification
# max   73.000000  410.369176         0.560000        7.376000
# min    5.732500  362.900338        -0.090000       -1.074000
# mean  33.859361  384.489030         0.190147        2.883544
# sem    1.227241    0.793913         0.009696        0.133771
#        OCH-700  OCH-2000  Ice_index  Salinity
# max   6.580000  2.540000  15.485000  0.008720
# min  -4.590000 -2.660000   3.566000  0.002220
# mean  0.462059  0.056422  10.706833  0.005264
# sem   0.204433  0.106732   0.237716  0.000107

# %%
summary_df1
# Out:
#       Sea_level     Sea_CO2  Sea_Temperature  Stratification
# max   73.000000  410.369176         0.560000        7.376000
# min    5.732500  362.900338        -0.090000       -1.074000
# mean  33.859361  384.489030         0.190147        2.883544
# sem    1.227241    0.793913         0.009696        0.133771

# %%
summary_df2
# Out:
#        OCH-700  OCH-2000  Ice_index  Salinity
# max   6.580000  2.540000  15.485000  0.008720
# min  -4.590000 -2.660000   3.566000  0.002220
# mean  0.462059  0.056422  10.706833  0.005264
# sem   0.204433  0.106732   0.237716  0.000107

# %%
# data = data.drop('Index', axis=1)
# data

# %%
# Import the whole dataset
data = pd.read_excel('final_dataset.xlsx', sheet_name = 0, index_col=0)
data = data.drop('Index', axis = 1)
data
# Out:
#      Sea_level     Sea_CO2  Sea_Temperature  Stratification  OCH-700  \
# 1    11.362857  374.337369             0.08           2.592    -4.13
# 2     8.350000  367.689260             0.11           2.948    -4.09
# 3     6.470000  365.933918             0.13           2.333    -3.92
# 4     8.370000  383.682120             0.08           2.371    -3.61
# 5     5.732500  391.892556             0.05           2.055    -3.50
# ..         ...         ...              ...             ...      ...
# 200  69.500000  395.057044             0.44           5.994     5.76
# 201  71.733333  396.693649             0.37           5.799     5.60
# 202  73.000000  401.322743             0.38           6.170     5.60
# 203  71.433333  385.674925             0.38           6.483     5.04
# 204  68.100000  377.579679             0.39           6.752     6.21
#
#      OCH-2000  Ice_index  Salinity
# 1       -2.53     14.391   0.00382
# 2       -2.48     15.193   0.00367
# ...

# %%
# If you have not installed scikit-learn, run the line below:
# !pip install scikit-learn

# import pandas as pd
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler

# Import the CSV file
# data = pd.read_csv('california_housing_train_subset.csv')
X = data.drop('Sea_level', axis=1)
# scaler = StandardScaler()
# X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)
y = data['Sea_level']
# y_scaled = pd.Series(scaler.fit_transform(y.values.reshape(-1, 1)).flatten(), name='median_house_value')

# Build a OLS model
# model = sm.OLS(y_scaled, sm.add_constant(X_scaled)).fit()
# model.summary()

ols_model = sm.OLS(y, sm.add_constant(X)).fit()
ols_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              Sea_level   R-squared:                       0.941
# Model:                            OLS   Adj. R-squared:                  0.939
# Method:                 Least Squares   F-statistic:                     447.0
# Date:                Wed, 13 Dec 2023   Prob (F-statistic):          8.16e-117
# Time:                        15:49:21   Log-Likelihood:                -584.40
# No. Observations:                 204   AIC:                             1185.
# Df Residuals:                     196   BIC:                             1211.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is already loaded and 'Index' column is set as the index or not included in df
# Calculate the correlation matrix
corr_matrix = df.drop(columns=['Sea_level']).corr()

# Plot the correlation matrix using seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Matrix")

# Save the plot
# plt.savefig('correlation_matrix_indep_variables_only.png')

plt.show()

# %%
# If you have not installed scikit-learn, run the line below:
# !pip install scikit-learn
# If you have not installed pandas numpy statsmodels, run the line below:
# !pip install pandas numpy statsmodels

# import pandas as pd
import numpy as np
# import statsmodels.api as sm
# from sklearn.preprocessing import StandardScaler

# # Import the data
# data = pd.read_csv('california_housing_train_subset.csv')
# X = data.drop('median_house_value', axis=1)
# scaler = StandardScaler()
# X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)
# y = data['median_house_value']
# y_scaled = pd.Series(scaler.fit_transform(y.values.reshape(-1, 1)).flatten(), name='median_house_value')

# # Fit an OLS model to get residuals
# ols_model = sm.OLS(y_scaled, sm.add_constant(X_scaled)).fit()
residuals = ols_model.resid

# Create weights based on the variance of residuals
weights = 1/ (residuals**2 + 1e-5)

# Fit the WLS model
wls_model = sm.WLS(y, sm.add_constant(X), weights=weights)
results = wls_model.fit()

# Show the results
print(results.summary())
# Out:
#                             WLS Regression Results
# ...
# Dep. Variable:              Sea_level   R-squared:                       1.000
# Model:                            WLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.057e+05
# Date:                Wed, 13 Dec 2023   Prob (F-statistic):               0.00
# Time:                        09:31:34   Log-Likelihood:                -463.90
# No. Observations:                 204   AIC:                             943.8
# Df Residuals:                     196   BIC:                             970.4
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const             134.5154      2.976     45.206      0.000     128.647     140.384
# ...

# %%
weights
# Out:
# 1      0.040525
# 2      1.267147
# 3      2.889472
# 4      0.092086
# 5      3.075456
#          ...
# 200    1.383632
# 201    0.136183
# 202    0.022372
# 203    0.014823
# 204    0.440702
# Length: 204, dtype: float64

# %%
import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

# Re-import the dataset due to the reset
df = pd.read_excel('final_dataset.xlsx')

# Prepare the data
df = df.drop('Unnamed: 0', axis=1)
df = df.set_index('Index')
Y = df['Sea_level']
X = df.drop('Sea_level', axis=1)

# Add a constant to the independent variable set (for the intercept)
X = add_constant(X)

# Calculate VIF for each explanatory variable
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns

# VIF calculation can be infinity if a feature is a perfect linear combination of others.
# To avoid division by zero in VIF calculation, we add a small value to the denominator.
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

vif_data
# Out:
#            feature          VIF
# 0            const  2155.911528
# 1          Sea_CO2     1.676362
# 2  Sea_Temperature    11.816146
# 3   Stratification    10.588149
# 4          OCH-700    15.583770
# 5         OCH-2000    13.505001
# 6        Ice_index     1.467124
# 7         Salinity     2.652212

# %%
X_reduced = X.drop(['OCH-700'], axis=1)
vif_data_reduced = pd.DataFrame()
vif_data_reduced["feature"] = X_reduced.columns
vif_data_reduced["VIF"] = [variance_inflation_factor(X_reduced.values, i) for i in range(X_reduced.shape[1])]

vif_data_reduced
# Out:
#            feature          VIF
# 0            const  2147.504055
# 1          Sea_CO2     1.675631
# 2  Sea_Temperature    11.683188
# 3   Stratification     9.568554
# 4         OCH-2000     3.979256
# 5        Ice_index     1.465167
# 6         Salinity     2.504883

# %%
# Removing 'Sea_Temperature' next and recalculating VIFs
X_reduced = X_reduced.drop(['Sea_Temperature'], axis=1)
vif_data_reduced = pd.DataFrame()
vif_data_reduced["feature"] = X_reduced.columns
vif_data_reduced["VIF"] = [variance_inflation_factor(X_reduced.values, i) for i in range(X_reduced.shape[1])]

vif_data_reduced
# Out:
#           feature          VIF
# 0           const  2131.631653
# 1         Sea_CO2     1.668511
# 2  Stratification     1.779577
# 3        OCH-2000     3.350130
# 4       Ice_index     1.458826
# 5        Salinity     2.490719

# %%
# Now that we have selected the independent variables with reduced multicollinearity,
# we can perform OLS regression again with the reduced set of variables.

# Removing 'Sea_Temperature' and 'OCH-700' from the original X variable set
X_final = X.drop(['Sea_Temperature', 'OCH-700'], axis=1)

# Perform OLS regression with the reduced set of variables
ols_model_final = sm.OLS(Y, X_final)
ols_results_final = ols_model_final.fit()

# Get a summary of the final OLS model
ols_results_final_summary = ols_results_final.summary()
ols_results_final_summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              Sea_level   R-squared:                       0.922
# Model:                            OLS   Adj. R-squared:                  0.920
# Method:                 Least Squares   F-statistic:                     464.9
# Date:                Wed, 13 Dec 2023   Prob (F-statistic):          2.59e-107
# Time:                        15:49:39   Log-Likelihood:                -613.62
# No. Observations:                 204   AIC:                             1239.
# Df Residuals:                     198   BIC:                             1259.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
X_final
# Out:
#          const     Sea_CO2  Stratification  OCH-2000  Ice_index  Salinity
# Index
# 2003-01    1.0  374.337369           2.592     -2.53     14.391   0.00382
# 2003-02    1.0  367.689260           2.948     -2.48     15.193   0.00367
# 2003-03    1.0  365.933918           2.333     -2.66     15.485   0.00328
# 2003-04    1.0  383.682120           2.371     -2.57     14.512   0.00314
# 2003-05    1.0  391.892556           2.055     -2.63     13.016   0.00262
# ...        ...         ...             ...       ...        ...       ...
# 2019-08    1.0  395.057044           5.994      2.54      5.026   0.00570
# 2019-09    1.0  396.693649           5.799      2.08      4.364   0.00654
# 2019-10    1.0  401.322743           6.170      2.03      5.735   0.00641
# 2019-11    1.0  385.674925           6.483      2.02      9.353   0.00621
# 2019-12    1.0  377.579679           6.752      2.33     11.903   0.00615
#
# [204 rows x 6 columns]

# %%
corr_matrix = X_final.drop('const', axis=1).corr()

# Plot the correlation matrix using seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Matrix")

# Save the plot
# plt.savefig('correlation_matrix.png')

plt.show()

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt

# Assuming ols_results_final is your final fitted OLS model
residuals = ols_results_final.resid

# Creating a Q-Q plot
plt.figure(figsize=(8, 6))
sm.qqplot(residuals, line='s')  # 's' indicates a standardized line
plt.title('Q-Q Plot of Residuals')

# Save the plot
# plt.savefig('Q-Q_plot.png')

plt.show()

# %%
from scipy import stats

# Assuming 'residuals' are from your final OLS model 'ols_results_final'
residuals = ols_results_final.resid

# Performing the Jarque-Bera test on the residuals
jarque_bera_test = stats.jarque_bera(residuals)

# Jarque-Bera test results: test statistic and p-value
jb_value, jb_p_value = jarque_bera_test

print("Jarque-Bera Test Statistic:", jb_value)
print("P-value:", jb_p_value)
# Out:
# Jarque-Bera Test Statistic: 3.276029360007084
# P-value: 0.19436553728660869

# %%
from statsmodels.stats.stattools import durbin_watson

# Performing the Durbin-Watson test
dw_statistic = durbin_watson(residuals)

print("Durbin-Watson statistic:", dw_statistic)
# Out:
# Durbin-Watson statistic: 0.4728188608612157

# %%
import statsmodels.api as sm
import numpy as np

# Step 1: Initial OLS Regression
model = sm.OLS(Y, X_final)
results = model.fit()
residuals = results.resid

# ols_results_final

# Initialize variables for the iterative process
rho = 1  # Initial guess for the autocorrelation coefficient
tolerance = 1e-6  # Convergence tolerance
max_iter = 100  # Maximum number of iterations
iter_count = 0

while iter_count < max_iter:
    iter_count += 1
    
    # Step 2: Estimate the first-order autocorrelation (rho) of the residuals
    rho_new = np.corrcoef(residuals[:-1], residuals[1:])[0, 1]

    # Check for convergence
    if abs(rho_new - rho) < tolerance:
        break
    
    rho = rho_new

    # Step 3: Transform the variables
    Y_transformed = Y[1:] - rho * Y[:-1]
    X_transformed = X_final[1:] - rho * X_final[:-1]

    # ... previous steps to estimate rho and transform variables ...

    # Drop NaNs from the transformed variables
    Y_transformed = Y_transformed.dropna()
    X_transformed = X_transformed.dropna()

    # Check for and handle infinite values if they exist
    if np.isinf(X_transformed).values.any() or np.isinf(Y_transformed).values.any():
        X_transformed.replace([np.inf, -np.inf], np.nan, inplace=True)
        Y_transformed.replace([np.inf, -np.inf], np.nan, inplace=True)
        X_transformed.dropna(inplace=True)
        Y_transformed.dropna(inplace=True)

    # Step 4: Rerun OLS regression on the transformed variables
    model_transformed = sm.OLS(Y_transformed, X_transformed)
    results_transformed = model_transformed.fit()
    residuals = results_transformed.resid
    

# Print the final results
print("Converged after", iter_count, "iterations")
print("rho: ", rho)
print(results_transformed.summary())
print("Durbin-Watson statistic:", durbin_watson(residuals))
# Out:
# Converged after 3 iterations
# rho:  0.7641808747915738
#                             OLS Regression Results
# ...
# Dep. Variable:              Sea_level   R-squared:                       0.920
# Model:                            OLS   Adj. R-squared:                  0.918
# Method:                 Least Squares   F-statistic:                     452.0
# Date:                Wed, 13 Dec 2023   Prob (F-statistic):          1.63e-105
# Time:                        09:31:36   Log-Likelihood:                -315.68
# No. Observations:                 202   AIC:                             643.4
# Df Residuals:                     196   BIC:                             663.2
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
from statsmodels.stats.stattools import durbin_watson

# Performing the Durbin-Watson test
dw_statistic = durbin_watson(results_transformed.resid)

print("Durbin-Watson statistic:", dw_statistic)
# Out:
# Durbin-Watson statistic: 0.46621978229547467

# %%
from statsmodels.regression.linear_model import OLS
from statsmodels.tsa.stattools import yule_walker

# Assume `Y` is the dependent variable and `X_final` is the independent variable
model = OLS(Y, X_final).fit()
residuals = model.resid

# Use the Yule-Walker equations to estimate the first-order autocorrelation coefficient (rho)
rho, _ = yule_walker(residuals, order=1)
rho=rho[0]
rho
# Out:
# 0.7621680497751809

# %%
# Drop the first observation since it will be NaN after the transformation
Y_dropped = Y.drop(index=Y.index[0])
X_dropped = X_final.drop(index=X_final.index[0])

# Perform the Prais-Winsten transformation on all variables
Y_transformed = Y_dropped - rho * Y.shift(1).drop(index=Y.index[0])
X_transformed = X_dropped.subtract(rho * X_final.shift(1).drop(index=X_final.index[0]))

# Perform OLS regression on the transformed data
prais_winsten_model = sm.OLS(Y_transformed, X_transformed)
prais_winsten_results = prais_winsten_model.fit()

# Get a summary of the OLS model with Prais-Winsten transformed data
prais_winsten_results_summary = prais_winsten_results.summary()
prais_winsten_results_summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              Sea_level   R-squared:                       0.658
# Model:                            OLS   Adj. R-squared:                  0.649
# Method:                 Least Squares   F-statistic:                     75.68
# Date:                Wed, 13 Dec 2023   Prob (F-statistic):           5.65e-44
# Time:                        09:31:36   Log-Likelihood:                -508.78
# No. Observations:                 203   AIC:                             1030.
# Df Residuals:                     197   BIC:                             1049.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
import numpy as np
from statsmodels.tsa.stattools import acf
from statsmodels.regression.linear_model import GLS
# Estimate the first-order autocorrelation coefficient
acf_coefficient = acf(ols_results_final.resid, fft=False, nlags=1)[1]

# Number of observations
n = len(ols_results_final.resid)

# Constructing a Toeplitz matrix for the GLS omega matrix
toeplitz_matrix = acf_coefficient ** np.abs(np.subtract.outer(np.arange(n), np.arange(n)))

# Apply the GLS model using the Toeplitz matrix as the omega matrix
gls_toeplitz_model = GLS(Y, X_final, sigma=toeplitz_matrix)
gls_toeplitz_results = gls_toeplitz_model.fit()

# Get a summary of the GLS model results with Toeplitz omega matrix
gls_toeplitz_results_summary = gls_toeplitz_results.summary()
gls_toeplitz_results_summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             GLS Regression Results
# ...
# Dep. Variable:              Sea_level   R-squared:                       0.677
# Model:                            GLS   Adj. R-squared:                  0.669
# Method:                 Least Squares   F-statistic:                     83.09
# Date:                Wed, 13 Dec 2023   Prob (F-statistic):           1.02e-46
# Time:                        15:49:52   Log-Likelihood:                -511.46
# No. Observations:                 204   AIC:                             1035.
# Df Residuals:                     198   BIC:                             1055.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
toeplitz_matrix
# Out:
# array([[1.00000000e+00, 7.58431932e-01, 5.75218995e-01, ...,
#         7.29858264e-25, 5.53547813e-25, 4.19828337e-25],
#        [7.58431932e-01, 1.00000000e+00, 7.58431932e-01, ...,
#         9.62325336e-25, 7.29858264e-25, 5.53547813e-25],
#        [5.75218995e-01, 7.58431932e-01, 1.00000000e+00, ...,
#         1.26883547e-24, 9.62325336e-25, 7.29858264e-25],
#        ...,
#        [7.29858264e-25, 9.62325336e-25, 1.26883547e-24, ...,
#         1.00000000e+00, 7.58431932e-01, 5.75218995e-01],
#        [5.53547813e-25, 7.29858264e-25, 9.62325336e-25, ...,
#         7.58431932e-01, 1.00000000e+00, 7.58431932e-01],
#        [4.19828337e-25, 5.53547813e-25, 7.29858264e-25, ...,
#         5.75218995e-01, 7.58431932e-01, 1.00000000e+00]])

# %%
ols_results_final_summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              Sea_level   R-squared:                       0.922
# Model:                            OLS   Adj. R-squared:                  0.920
# Method:                 Least Squares   F-statistic:                     464.9
# Date:                Wed, 13 Dec 2023   Prob (F-statistic):          2.59e-107
# Time:                        09:31:34   Log-Likelihood:                -613.62
# No. Observations:                 204   AIC:                             1239.
# Df Residuals:                     198   BIC:                             1259.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
import matplotlib.pyplot as plt

# Assuming 'residuals' are from your final OLS model 'ols_results_final'
# And 'fitted_values' are the predicted values from the same model
fitted_values = ols_results_final.fittedvalues

# Creating a residual plot
plt.figure(figsize=(8, 6))

max_value = residuals.max()
min_value = residuals.min()
range_value = max_value - min_value

plt.ylim(bottom = min_value - range_value*0.5, top = max_value + range_value*0.5)
plt.scatter(fitted_values, residuals, alpha=0.5)
plt.axhline(y=0, color='r', linestyle='--')  # Horizontal line at 0
plt.xlabel('Fitted Values')
plt.ylabel('Residuals')
plt.title('Residual Plot')

# Save the plot
# plt.savefig('residual_plot.png')

plt.show()

# %%
max_value
# Out:
# 14.209421514489144

# %%
from statsmodels.stats.diagnostic import het_white
import numpy as np

# Assuming 'ols_results_final' is your OLS regression results
# Extract residuals
residuals = ols_results_final.resid

# Extract the independent variables used in the regression
# If you have included a constant in the model, ensure it's included here as well
indep_vars = ols_results_final.model.exog

# Perform the White test
test_stat, p_value, f_stat, f_p_value = het_white(residuals, indep_vars)

print("White test statistic:", test_stat)
print("p-value:", p_value)
# Out:
# White test statistic: 72.93573036476704
# p-value: 5.997911192147009e-08

# %%
###### residuals = ols_results_final.resid

# Create weights based on the variance of residuals
weights = 1/ (residuals**2 + 1e-5)

# Fit the WLS model
wls_model_final = sm.WLS(Y, sm.add_constant(X_final), weights=weights)
wls_results_final = wls_model_final.fit()

# Show the results
wls_results_final.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             WLS Regression Results
# ...
# Dep. Variable:              Sea_level   R-squared:                       0.995
# Model:                            WLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                     8645.
# Date:                Wed, 13 Dec 2023   Prob (F-statistic):          1.29e-229
# Time:                        09:31:38   Log-Likelihood:                -494.99
# No. Observations:                 204   AIC:                             1002.
# Df Residuals:                     198   BIC:                             1022.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
weights
# Out:
# Index
# 2003-01    0.070107
# 2003-02    2.273188
# 2003-03    2.030219
# 2003-04    0.052275
# 2003-05    0.113495
#              ...
# 2019-08    0.418863
# 2019-09    0.021559
# 2019-10    0.008635
# 2019-11    0.008994
# 2019-12    0.027589
# Length: 204, dtype: float64

# %%
vif_data_final = pd.DataFrame()
vif_data_final["feature"] = X_final.columns
vif_data_final["VIF"] = [variance_inflation_factor(X_final.values, i) for i in range(X_final.shape[1])]

vif_data_final
# Out:
#           feature          VIF
# 0           const  2131.631653
# 1         Sea_CO2     1.668511
# 2  Stratification     1.779577
# 3        OCH-2000     3.350130
# 4       Ice_index     1.458826
# 5        Salinity     2.490719

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt

# Assuming ols_results_final is your final fitted OLS model
residuals = wls_results_final.resid

# Creating a Q-Q plot
plt.figure(figsize=(8, 6))
sm.qqplot(residuals, line='s')  # 's' indicates a standardized line
plt.title('Q-Q Plot of Residuals (WLS)')

# Save the plot
# plt.savefig('Q-Q_plot_wls.png')

plt.show()

# %%
import matplotlib.pyplot as plt

fitted_values = wls_results_final.fittedvalues

# Creating a residual plot
plt.figure(figsize=(8, 6))

max_value = residuals.max()
min_value = residuals.min()
range_value = max_value - min_value

plt.ylim(bottom = min_value - range_value*0.5, top = max_value + range_value*0.5)
plt.scatter(fitted_values, residuals, alpha=0.5)
plt.axhline(y=0, color='r', linestyle='--')  # Horizontal line at 0
plt.xlabel('Fitted Values')
plt.ylabel('Residuals')
plt.title('Residual Plot (WLS)')

# Save the plot
# plt.savefig('residual_plot_wls.png')

plt.show()

# %%
X_raw = X_final.drop('const', axis = 1)
X_raw
# Out:
#             Sea_CO2  Stratification  OCH-2000  Ice_index  Salinity
# Index
# 2003-01  374.337369           2.592     -2.53     14.391   0.00382
# 2003-02  367.689260           2.948     -2.48     15.193   0.00367
# 2003-03  365.933918           2.333     -2.66     15.485   0.00328
# 2003-04  383.682120           2.371     -2.57     14.512   0.00314
# 2003-05  391.892556           2.055     -2.63     13.016   0.00262
# ...             ...             ...       ...        ...       ...
# 2019-08  395.057044           5.994      2.54      5.026   0.00570
# 2019-09  396.693649           5.799      2.08      4.364   0.00654
# 2019-10  401.322743           6.170      2.03      5.735   0.00641
# 2019-11  385.674925           6.483      2.02      9.353   0.00621
# 2019-12  377.579679           6.752      2.33     11.903   0.00615
#
# [204 rows x 5 columns]

# %%
# import numpy as np

# residuals = ols_results_final.resid

# # Create weights based on the variance of residuals
# weights = 1/ (residuals**4 + 1e-6)

# # # Fit the WLS model
# # wls_model_final = sm.WLS(Y, sm.add_constant(X_final), weights=weights)
# # wls_results_final = wls_model_final.fit()

# # # Show the results
# # wls_results_final.summary()

# X_raw = X_final.drop('const', axis = 1)
# # X_final_W = sm.add_constant(X_raw)

# np_weights = weights.to_numpy()

# W = np.diag(np.sqrt(np_weights))

# # Perform OLS regression with W
# ols_model_W = sm.OLS(W@Y, sm.add_constant(W@X_raw))
# ols_results_W = ols_model_W.fit()

# # Get a summary of the final OLS model
# ols_results_W_summary = ols_results_W.summary()
# ols_results_W_summary

# %%
# import statsmodels.api as sm
# import matplotlib.pyplot as plt

# # Assuming ols_results_final is your final fitted OLS model
# residuals = ols_results_W.resid

# # Creating a Q-Q plot
# plt.figure(figsize=(8, 6))
# sm.qqplot(residuals, line='s')  # 's' indicates a standardized line
# plt.title('Q-Q Plot of Residuals (altered_WLS)')

# # Save the plot
# # plt.savefig('Q-Q_plot_W.png')

# plt.show()

# %%
# import matplotlib.pyplot as plt

# fitted_values = ols_results_W.fittedvalues

# # Creating a residual plot
# plt.figure(figsize=(8, 6))

# max_value = residuals.max()
# min_value = residuals.min()
# range_value = max_value - min_value

# plt.ylim(bottom = min_value - range_value*0.5, top = max_value + range_value*0.5)
# # plt.xlim(0, 100)
# plt.scatter(fitted_values, residuals, alpha=0.5)
# plt.axhline(y=0, color='r', linestyle='--')  # Horizontal line at 0
# plt.xlabel('Fitted Values')
# plt.ylabel('Residuals')
# plt.title('Residual Plot (altered_WLS)')

# # Save the plot
# # plt.savefig('residual_plot_W.png')

# plt.show()

# %%
# from statsmodels.stats.diagnostic import het_white
# import numpy as np

# # Assuming 'ols_results_final' is your OLS regression results
# # Extract residuals
# residuals = ols_results_W.resid

# # Extract the independent variables used in the regression
# # If you have included a constant in the model, ensure it's included here as well
# indep_vars = ols_results_W.model.exog

# # Perform the White test
# test_stat, p_value, f_stat, f_p_value = het_white(residuals, indep_vars)

# print("White test statistic:", test_stat)
# print("p-value:", p_value)

# %%
# pd.DataFrame(indep_vars)

# %%
# residuals = ols_results_final.resid

# # Create weights based on the variance of residuals
# weights = 1/ (residuals**4 + 1e-6)

# # Fit the WLS model
# wls_model_final = sm.WLS(Y, sm.add_constant(X_final), weights=weights)
# wls_results_final = wls_model_final.fit()

# # Show the results
# wls_results_final.summary()

# %%
from statsmodels.stats.diagnostic import het_white
import numpy as np

# Assuming 'ols_results_final' is your OLS regression results
# Extract residuals
residuals = wls_results_final.resid

# Extract the independent variables used in the regression
# If you have included a constant in the model, ensure it's included here as well
indep_vars = wls_results_final.model.exog

# Perform the White test
test_stat, p_value, f_stat, f_p_value = het_white(residuals, indep_vars)

print("White test statistic:", test_stat)
print("p-value:", p_value)
# Out:
# White test statistic: 73.33606806195033
# p-value: 5.1493418676826174e-08

# %%
# print((wls_results_final.resid - ols_results_final.resid).sort_values())

# %%
# gls_toeplitz_results_summary

# %%
gls_results_final = gls_toeplitz_results

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt

# Assuming ols_results_final is your final fitted OLS model
residuals = gls_results_final.resid

# Creating a Q-Q plot
plt.figure(figsize=(8, 6))
sm.qqplot(residuals, line='s')  # 's' indicates a standardized line
plt.title('Q-Q Plot of Residuals (GLS)')

# Save the plot
# plt.savefig('Q-Q_plot_gls.png')

plt.show()

# %%
import matplotlib.pyplot as plt

fitted_values = gls_results_final.fittedvalues

# Creating a residual plot
plt.figure(figsize=(8, 6))

max_value = residuals.max()
min_value = residuals.min()
range_value = max_value - min_value

plt.ylim(bottom = min_value - range_value*0.5, top = max_value + range_value*0.5)
plt.scatter(fitted_values, residuals, alpha=0.5)
plt.axhline(y=0, color='r', linestyle='--')  # Horizontal line at 0
plt.xlabel('Fitted Values')
plt.ylabel('Residuals')
plt.title('Residual Plot (GLS)')

# Save the plot
# plt.savefig('residual_plot_gls.png')

plt.show()

# %%
from statsmodels.stats.diagnostic import het_white
import numpy as np

# Assuming 'ols_results_final' is your OLS regression results
# Extract residuals
residuals = gls_results_final.resid

# Extract the independent variables used in the regression
# If you have included a constant in the model, ensure it's included here as well
indep_vars = gls_results_final.model.exog

# Perform the White test
test_stat, p_value, f_stat, f_p_value = het_white(residuals, indep_vars)

print("White test statistic:", test_stat)
print("p-value:", p_value)
# Out:
# White test statistic: 69.45767611909642
# p-value: 2.232713835314266e-07

# %% [markdown]
# ## Backtesting

# %%
import pandas as pd
from statsmodels.regression.linear_model import GLS
# from numpy import toeplitz
from sklearn.metrics import mean_squared_error
from math import sqrt
# Correcting the import for toeplitz
from scipy.linalg import toeplitz

# We will proceed with the assumption that we have the actual predictions.
# Now let's load the dataset and calculate the RMSE with the test data and the assumed predictions.

# Load the dataset from the Excel file
file_path = 'final_dataset_backtesting.xlsx'
dataset = pd.read_excel(file_path)

# Assuming the dataset contains columns for all independent variables (X_final) 
# and the dependent variable (Y) with the same names as used in the model fitting

# For the purpose of the example, I'm assuming the dependent variable is named 'Sea_level'
# and the independent variables are all other columns.
Y_test = dataset['Sea_level']
X_test = dataset[['Sea_CO2', 'Stratification', 'OCH-2000', 'Ice_index', 'Salinity']]

# Back-predict using GLS
Y_pred_gls = gls_toeplitz_results.predict(sm.add_constant(X_test))

# Calculate the RMSE
rmse = sqrt(mean_squared_error(Y_test, Y_pred_gls))

rmse, Y_test.head(), Y_pred_gls.head()  # Displaying first few actual and predicted values alongside RMSE
# Out:
# (5.739711986753132,
#  0   -23.170000
#  1   -19.863333
#  2   -24.380000
#  3   -18.796667
#  4   -23.963333
#  Name: Sea_level, dtype: float64,
#  0   -19.935024
#  1   -20.166408
#  2   -20.791020
#  3   -19.584073
#  4   -19.784233
#  dtype: float64)

# %%
# Back-predict using OLS
Y_pred_ols = ols_results_final.predict(sm.add_constant(X_test))

# Calculate the RMSE
rmse = sqrt(mean_squared_error(Y_test, Y_pred_ols))

rmse, Y_test.head(), Y_pred_ols.head()  # Displaying first few actual and predicted values alongside RMSE
# Out:
# (5.804226203529527,
#  0   -23.170000
#  1   -19.863333
#  2   -24.380000
#  3   -18.796667
#  4   -23.963333
#  Name: Sea_level, dtype: float64,
#  0   -21.958135
#  1   -22.291212
#  2   -23.945956
#  3   -23.629308
#  4   -25.442735
#  dtype: float64)

# %%
# # Predictions using the fitted GLS model
# # Y_pred = gls_toeplitz_results.predict(X_test)
# ols_results_final
